# %% [markdown]
# # Загрузка CSV
# который сформировали с помощью scrapy

# %%
import pandas as pd
import matplotlib.pyplot as plt

import warnings; warnings.filterwarnings(action='once')
# %matplotlib inline

# %%
#df = pd.DataFrame()
df = pd.read_csv("insta.csv", sep=",")
df['date'] = pd.to_datetime(df['time'],unit='s')
df.head()
# Out:
#       user_id              post_id   likes        time                date
# 0  5630155732  2667255802274097407   92329  1632181690 2021-09-20 23:48:10
# 1  5630155732  2657655944777117333  102706  1631037298 2021-09-07 17:54:58
# 2  5630155732  2655447344599154985   94790  1630774013 2021-09-04 16:46:53
# 3  5630155732  2653293066322201608   19611  1630517258 2021-09-01 17:27:38
# 4  5630155732  2651913582551592337   82704  1630352771 2021-08-30 19:46:11

# %%
plt.figure(figsize=(16,10), dpi= 80)
plt.plot('date', 'likes', data=df, color='tab:red')

plt.yticks(fontsize=12, alpha=.7)
plt.title("Likes", fontsize=22)
plt.grid(axis='both', alpha=.3)

plt.show()
